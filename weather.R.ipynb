# %%
install.packages("tidyverse")
install.packages("here")
install.packages("skimr")
install.packages("janitor")
# Out:
# Installing package into 'C:/Users/S542403/Documents/R/win-library/4.0'
# (as 'lib' is unspecified)
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\S542403\AppData\Local\Temp\RtmpiAlqCT\downloaded_packages
# Installing package into 'C:/Users/S542403/Documents/R/win-library/4.0'
# (as 'lib' is unspecified)
# package 'here' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\S542403\AppData\Local\Temp\RtmpiAlqCT\downloaded_packages
# Installing package into 'C:/Users/S542403/Documents/R/win-library/4.0'
# (as 'lib' is unspecified)
# package 'skimr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\S542403\AppData\Local\Temp\RtmpiAlqCT\downloaded_packages
# Installing package into 'C:/Users/S542403/Documents/R/win-library/4.0'
# (as 'lib' is unspecified)
# package 'janitor' successfully unpacked and MD5 sums checked
#
# ...

# %%
library("tidyverse")
library("here")
library("skimr")
library("janitor")
# Out:
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.1 --
#
# v ggplot2 3.3.3     v purrr   0.3.4
# v tibble  3.1.1     v dplyr   1.0.5
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
# here() starts at C:/Users/S542403/Documents/GitHub/Data-Analysis-using-R
#
#
# Attaching package: 'janitor'
#
#
# The following objects are masked from 'package:stats':
#
#     chisq.test, fisher.test

# %%
weather_df <- read_csv("weather.csv")
# Out:
# -- Column specification ------------------------------------------------------------------------------------------------
# cols(
#   YEAR = col_double(),
#   JAN = col_double(),
#   FEB = col_double(),
#   MAR = col_double(),
#   APR = col_double(),
#   MAY = col_double(),
#   JUN = col_double(),
#   JUL = col_double(),
#   AUG = col_double(),
#   SEP = col_double(),
#   OCT = col_double(),
#   NOV = col_double(),
#   DEC = col_double()
# )

# %%
weather_df
# Out:
#     YEAR JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV
# 1   1901 17.99 19.43 23.49 26.41 28.28 28.60 27.49 26.98 26.26 25.08 21.73
# 2   1902 19.00 20.39 24.10 26.54 28.68 28.44 27.29 27.05 25.95 24.37 21.33
# 3   1903 18.32 19.79 22.46 26.03 27.93 28.41 28.04 26.63 26.34 24.57 20.96
# 4   1904 17.77 19.39 22.95 26.73 27.83 27.85 26.84 26.73 25.84 24.36 21.07
# 5   1905 17.40 17.79 21.78 24.84 28.32 28.69 27.67 27.47 26.29 26.16 22.07
# 6   1906 17.50 19.14 22.21 26.53 29.06 28.02 27.46 26.82 26.23 24.75 21.93
# 7   1907 19.27 19.42 22.03 26.98 27.52 27.66 27.28 26.38 26.26 24.72 22.11
# 8   1908 18.35 19.73 22.93 27.06 28.07 28.49 27.16 26.41 25.74 24.25 21.06
# 9   1909 17.79 19.05 23.40 25.76 27.97 27.67 26.56 26.43 25.47 24.37 22.01
# 10  1910 18.14 19.72 22.90 25.96 28.36 27.72 26.93 26.61 25.98 24.04 20.72
# 11  1911 18.52 19.18 22.05 26.00 28.55 28.02 27.44 27.04 26.22 24.57 21.10
# 12  1912 18.60 20.84 22.93 26.21 28.30 28.53 27.49 26.68 25.81 24.44 21.00
# ...

# %%
filter()
# Out:
# Error in View("weather_df"): 'View()' not yet supported in the Jupyter R kernel
# Traceback:
#
# 1. View("weather_df")
# 2. stop(sQuote("View()"), " not yet supported in the Jupyter R kernel")

# %%
#Average temperature in winter and in summer overall.
weather_df %>% 
summarize(winter_mean = (mean(JAN)+mean(FEB)+mean(MAR))/3, summer_mean = (mean(MAY)+mean(JUN)+mean(JUL))/3)
# Out:
#   winter_mean summer_mean
# 1 20.66513    28.01886

# %%
#Compare the february and october temperatures using plots.
ggplot(data = weather_df)+
geom_point(aes(x=FEB, y=OCT))+
labs(title="FEB vs OCT")
# Out:
# plot without title

# %%
#Average temperature in winter and in summer in 1942.
weather_df %>% 
filter(YEAR == 1942) %>% 
summarize(winter_mean = (JAN+FEB+MAR)/3, summer_mean =(MAY+JUN+JUL)/3)
# Out:
#   winter_mean summer_mean
# 1 20.66667    28.30333

# %%
#Temperature difference between winter and summer in 2001
weather_df %>% 
filter(YEAR == 2001) %>% 
summarize(diff_win_sum = abs(((JAN+FEB+MAR)/3)- ((MAY+JUN+JUL)/3)))
# Out:
#   diff_win_sum
# 1 7.2

# %%
#Find the avg temperature in 1971.
weather_df %>%
filter(YEAR==1971) %>% 
subset(select=c(JAN:DEC)) %>% 
rowMeans()
# Out:
# [1] 23.90917

# %%
#Find the avg temperature till now 
new_weather_df <- subset(weather_df, select = c(JAN:DEC))
mean(as.matrix(new_weather_df))
# Out:
# [1] 24.29416

# %%
#Which month has the lowest, highest temperatures, overall?
df <-subset(weather_df, select=c(JAN:DEC))
capture.output(cat("The lowest temperature recored in the month of ", names(df)[which.min(apply(df,MARGIN=2,min))]))
capture.output(cat("The highest temperature recorded in the month of ",names(df)[which.max(apply(df,MARGIN=2,max))]))
# Out:
# [1] "The lowest temperature recored in the month of  JAN"
# [1] "The highest temperature recorded in the month of  MAY"

# %%
# Out:
# [1] "MAY"

# %%
# Out:
#     JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV   DEC
# 1   17.99 19.43 23.49 26.41 28.28 28.60 27.49 26.98 26.26 25.08 21.73 18.95
# 2   19.00 20.39 24.10 26.54 28.68 28.44 27.29 27.05 25.95 24.37 21.33 18.78
# 3   18.32 19.79 22.46 26.03 27.93 28.41 28.04 26.63 26.34 24.57 20.96 18.29
# 4   17.77 19.39 22.95 26.73 27.83 27.85 26.84 26.73 25.84 24.36 21.07 18.84
# 5   17.40 17.79 21.78 24.84 28.32 28.69 27.67 27.47 26.29 26.16 22.07 18.71
# 6   17.50 19.14 22.21 26.53 29.06 28.02 27.46 26.82 26.23 24.75 21.93 19.55
# 7   19.27 19.42 22.03 26.98 27.52 27.66 27.28 26.38 26.26 24.72 22.11 18.46
# 8   18.35 19.73 22.93 27.06 28.07 28.49 27.16 26.41 25.74 24.25 21.06 18.15
# 9   17.79 19.05 23.40 25.76 27.97 27.67 26.56 26.43 25.47 24.37 22.01 18.86
# 10  18.14 19.72 22.90 25.96 28.36 27.72 26.93 26.61 25.98 24.04 20.72 18.05
# 11  18.52 19.18 22.05 26.00 28.55 28.02 27.44 27.04 26.22 24.57 21.10 18.76
# ...

# %%
# Out:
# [1] "MAY"
